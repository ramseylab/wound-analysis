# %%
import numpy as np
import cv2
from PIL import Image
import os

# %%
def find_min_offset(hr_img, lr_img, true_lr_img, lr_mask, scale=17.85):
    """
    hr_img: 4k x 6k high-resolution image
    true_lr_img: 224 x 336 color image (down-sampled from hr_img by 17.85-fold)
    lr_img : 224 x 224 low-resolution image
    lr_mask: 224 x 224 binary segmentation mask (metadata corresponds to hr_img)
    scale: down-sampling factor
    """
    min_distance = float('inf')
    min_offset = 0
    lr_h, lr_w, _ = lr_img.shape
    for i in range(0, 112):
        crop_img = lr_img[:, i:i + 224, :]
        distance = np.sum(np.square(true_lr_img - crop_img))
        if distance < min_distance:
            min_distance = distance
            min_offset = i

    j = int(scale * min_offset)
    upscaled_mask = cv2.resize(lr_mask, (hr_img.shape[1], hr_img.shape[0]))
    return j, upscaled_mask

# %%
def downsample_image(img, scale_factor):
    """
    img: original image
    scale_factor: down-sampling factor
    """
    h, w = img.shape[:2]
    print(h,w)
    new_h, new_w = int(h / scale_factor), int(w / scale_factor)
    return cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_LINEAR)

# %%
folder_dir = 'offset_image'
c = 0
hr_img_list = []
lr_img_list = []
lr_mask_list = []

for sub_folder in os.listdir(folder_dir):
    if sub_folder == 'hr_img':
        for image in os.listdir(folder_dir+'/'+sub_folder):
            hr_img_list.append(image)
    elif sub_folder == 'lr_img':
        for image in os.listdir(folder_dir+'/'+sub_folder):
            lr_img_list.append(image)
    elif sub_folder == 'lr_mask':
        for image in os.listdir(folder_dir+'/'+sub_folder):
            lr_mask_list.append(image)

# %%
lr_img_list.sort()
lr_mask_list.sort()
hr_img_list.sort()

# %%
offset_j_list=[]

for i in range(len(lr_img_list)):
    # reading images
    
    hr_img = cv2.imread('offset_image/hr_img/'+lr_img_list[i][:12]+'.JPG')
    true_lr_img = cv2.imread('offset_image/lr_img/'+lr_img_list[i])
    lr_mask = cv2.imread('offset_image/lr_mask/'+lr_img_list[i])
    
    #downsampling high_resolution image
    lr_img = downsample_image(hr_img, 17.85)
    print(lr_img.shape)
    
    # finding offset and upsclaing the masked images that corresponds to high resolution image.
    j , upscaled_mask = find_min_offset(hr_img, lr_img, true_lr_img, lr_mask, scale=17.85)
    offset_j_list.append((lr_img_list[i][:12]+'.JPG', j))
    cv2.imwrite('offset_image/hr_mask/'+lr_img_list[i][:12]+'.JPG', upscaled_mask)
# Out:
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)
# 4000 6000
# (224, 336, 3)

# %%
print(offset_j_list)
# Out:
# [('01-CON-D00-L.JPG', 749), ('01-CON-D02-L.JPG', 0), ('01-CON-D04-L.JPG', 714), ('01-CON-D07-L.JPG', 660), ('01-CON-D09-L.JPG', 963), ('01-CON-D11-L.JPG', 1017), ('01-CON-D14-L.JPG', 1017), ('01-CON-D16-L.JPG', 678), ('01-CON-D18-L.JPG', 392), ('01-CON-D21-L.JPG', 910), ('01-CON-D23-L.JPG', 589), ('01-CON-D25-L.JPG', 428), ('01-CON-D28-L.JPG', 1017), ('01-CON-D30-L.JPG', 1213), ('01-CON-D32-L.JPG', 892), ('02-CON-D00-L.JPG', 928), ('02-CON-D02-L.JPG', 892), ('02-CON-D04-L.JPG', 1035), ('02-CON-D07-L.JPG', 946), ('02-CON-D09-L.JPG', 1124), ('02-CON-D11-L.JPG', 1142), ('02-CON-D14-L.JPG', 1195), ('02-CON-D16-L.JPG', 1017), ('02-CON-D18-L.JPG', 1071), ('02-CON-D21-L.JPG', 1053), ('02-CON-D23-L.JPG', 1071), ('02-CON-D25-L.JPG', 1338), ('02-CON-D28-L.JPG', 1392), ('02-CON-D30-L.JPG', 1499), ('02-CON-D32-L.JPG', 856), ('03-CON-D00-R.JPG', 1124), ('03-CON-D02-R.JPG', 963), ('03-CON-D04-R.JPG', 1071), ('03-CON-D07-R.JPG', 910), ('03-CON-D09-R.JPG', 999), ('03-CON-D11-R.JPG', 1088), ('03-CON-D14-R.JPG', 1071), ('03-CON-D16-R.JPG', 517), ('03-CON-D18-R.JPG', 1267), ('03-CON-D21-R.JPG', 946), ('03-CON-D23-R.JPG', 731), ('03-CON-D25-R.JPG', 1035), ('03-CON-D28-R.JPG', 1017), ('03-CON-D30-R.JPG', 910), ('03-CON-D32-R.JPG', 374), ('04-CON-D00-R.JPG', 1106), ('04-CON-D02-R.JPG', 89), ('04-CON-D04-R.JPG', 1463), ('04-CON-D07-R.JPG', 1428), ('04-CON-D09-R.JPG', 1195), ('04-CON-D11-R.JPG', 1106), ('04-CON-D14-R.JPG', 1749), ('04-CON-D16-R.JPG', 1053), ('04-CON-D18-R.JPG', 1267), ('04-CON-D21-R.JPG', 1570), ('04-CON-D23-R.JPG', 1338), ('04-CON-D25-R.JPG', 1338), ('04-CON-D28-R.JPG', 1428), ('04-CON-D30-R.JPG', 1249), ('04-CON-D32-R.JPG', 821), ('05-CON-D02-L.JPG', 821), ('05-CON-D04-L.JPG', 1142), ('05-CON-D07-L.JPG', 1053), ('05-CON-D09-L.JPG', 517), ('05-CON-D11-L.JPG', 1320), ('05-CON-D14-L.JPG', 767), ('05-CON-D16-L.JPG', 1303), ('05-CON-D18-L.JPG', 1320), ('05-CON-D21-L.JPG', 1195), ('05-CON-D23-L.JPG', 838), ('05-CON-D25-L.JPG', 1927), ('05-CON-D28-L.JPG', 1445), ('05-CON-D30-L.JPG', 1570), ('05-CON-D32-L.JPG', 1624), ('06-CON-D00-L.JPG', 803), ('06-CON-D02-L.JPG', 1285), ('06-CON-D04-L.JPG', 928), ('06-CON-D07-L.JPG', 624), ('06-CON-D09-L.JPG', 1035), ('06-CON-D11-L.JPG', 892), ('06-CON-D14-L.JPG', 1231), ('06-CON-D16-L.JPG', 856), ('06-CON-D18-L.JPG', 946), ('06-CON-D21-L.JPG', 910), ('06-CON-D23-L.JPG', 892), ('06-CON-D25-L.JPG', 1624), ('07-CON-D00-R.JPG', 838), ('07-CON-D02-R.JPG', 589), ('07-CON-D04-R.JPG', 821), ('07-CON-D07-R.JPG', 1410), ('07-CON-D09-R.JPG', 821), ('07-CON-D11-R.JPG', 1231), ('07-CON-D14-R.JPG', 1017), ('07-CON-D16-R.JPG', 731), ('07-CON-D18-R.JPG', 714), ('07-CON-D21-R.JPG', 1303), ('07-CON-D23-R.JPG', 838), ('07-CON-D25-R.JPG', 1053), ('08-CON-D00-L.JPG', 928), ('08-CON-D02-L.JPG', 1410), ('08-CON-D04-L.JPG', 892), ('08-CON-D07-L.JPG', 892), ('08-CON-D09-L.JPG', 946), ('08-CON-D11-L.JPG', 1303), ('08-CON-D14-L.JPG', 928), ('08-CON-D16-L.JPG', 1517), ('08-CON-D18-L.JPG', 464), ('08-CON-D21-L.JPG', 910), ('08-CON-D23-L.JPG', 1088), ('08-CON-D25-L.JPG', 1124)]

# %%
import pandas as pd
df = pd.DataFrame(offset_j_list)
df.columns = ['high_resolution_image_name', 'offset_value']

# %%
df.to_csv('high_resolution_image_offset_values.csv')

# %%
df
# Out:
#     high_resolution_image_name  offset_value
# 0             01-CON-D00-L.JPG           749
# 1             01-CON-D02-L.JPG             0
# 2             01-CON-D04-L.JPG           714
# 3             01-CON-D07-L.JPG           660
# 4             01-CON-D09-L.JPG           963
# ..                         ...           ...
# 105           08-CON-D16-L.JPG          1517
# 106           08-CON-D18-L.JPG           464
# 107           08-CON-D21-L.JPG           910
# 108           08-CON-D23-L.JPG          1088
# 109           08-CON-D25-L.JPG          1124
#
# [110 rows x 2 columns]
