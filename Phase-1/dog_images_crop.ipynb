# %%
from PIL import Image
#from IPython.display import Image

# %%
# import the modules
import os
from os import listdir
 
# get the path/directory
folder_dir = "dog_dataset"

image_path_cropped_images = "dog_dataset_cropped_images"
os.mkdir(image_path_cropped_images)
c=0
for images in os.listdir(folder_dir):
    
    # check if the image ends with png
    if (images.endswith(".jpg")) or (images.endswith(".JPG")):
        c+=1
        print("name",images,c)
        im = Image.open(r'dog_dataset/'+images)
        
        # Size of the image in pixels (size of original image)
        # (This is not mandatory)
        width, height = im.size
        
        print('first image',width, height)
        # Setting the points for cropped image
        left = 25
        top = 5
        right = 5975
        bottom = 3995

        # Cropped image of above dimension
        # (It will not change original image)
        im1 = im.crop((left, top, right, bottom))
        width, height = im1.size
        
        print('second image',width, height)
        
        # Shows the image in image viewer
        #im.show()
        #im1.show()
        

        
        image = im1.save(f"{image_path}/"+images)
# Out:
# name 03-CON-D28-R.JPG 1
# first image 6000 4000
# second image 5950 3990
# name 03-CON-D16-R.JPG 2
# first image 6000 4000
# second image 5950 3990
# name 06-CON-D21-L.JPG 3
# first image 6000 4000
# second image 5950 3990
# name 04-CON-D25-R.JPG 4
# first image 6000 4000
# second image 5950 3990
# name 02-CON-D07-L.JPG 5
# first image 6000 4000
# second image 5950 3990
# name 01-CON-D18-L.JPG 6
# first image 6000 4000
# second image 5950 3990
# name 03-CON-D04-R.JPG 7
# first image 6000 4000
# second image 5950 3990
# name 01-CON-D04-L.JPG 8
# first image 6000 4000
# second image 5950 3990
# name 08-CON-D23-L.JPG 9
# first image 6000 4000
# second image 5950 3990
# name 06-CON-D14-L.JPG 10
# first image 6000 4000
# second image 5950 3990
# name 03-CON-D00-R.jpg 11
# first image 6000 4000
# second image 5950 3990
# name 10-CON-D18-R.JPG 12
# first image 6000 4000
# second image 5950 3990
# name 04-CON-D00-R.jpg 13
# first image 6000 4000
# second image 5950 3990
# ...
